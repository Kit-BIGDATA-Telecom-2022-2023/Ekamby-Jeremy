# %%
liste_horaire=[]
liste_horaire_V0=[]
liste_horaire_V1=[]
liste_horaire_V2=[]

# %%
import pandas as pd

# %% [markdown]
# # Extraction de données

# %%
from shutil import copyfileobj
from urllib import request


import datetime
 
dt_ref = datetime.datetime.combine(datetime.date(year=2020, month=11, day=8), datetime.time(hour=14, minute=0, second=0))
dt_ref_fin = datetime.datetime.combine(datetime.date(year=2020, month=11, day=9), datetime.time(hour=14, minute=0, second=0))

start_date = dt_ref
end_date = dt_ref_fin

while start_date < end_date:
       
    if dt_ref.time()==datetime.time(hour=15, minute=0, second=0):
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)        
        dt_ref += datetime.timedelta(minutes=120)
        
    if dt_ref.time()==datetime.time(17, 0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)
        dt_ref += datetime.timedelta(minutes=240)
              
    if dt_ref.time()==datetime.time(21, 0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)
        dt_ref += datetime.timedelta(minutes=420)
              
    if dt_ref.time()==datetime.time(4, 0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)
        dt_ref += datetime.timedelta(minutes=240)
        
    if dt_ref.time()==datetime.time(8, 0):  
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)
        dt_ref += datetime.timedelta(minutes=180)
        
    if dt_ref.time()==datetime.time(11, 0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)
        dt_ref += datetime.timedelta(minutes=180)
        
    if dt_ref.time()==datetime.time(hour=14, minute=0, second=0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)        
        dt_ref += datetime.timedelta(minutes=60)
        
    start_date=dt_ref
# Out:
# 20201108_140000
# 20201108_150000
# 20201108_170000
# 20201108_210000
# 20201109_040000
# 20201109_080000
# 20201109_110000
# 20201109_140000

# %%
dt_ref = datetime.datetime.combine(datetime.date(year=2020, month=11, day=8), datetime.time(hour=17, minute=0, second=0))
dt_ref_fin = datetime.datetime.combine(datetime.date(year=2021, month=1, day=7), datetime.time(hour=14, minute=0, second=0))

start_date = dt_ref
end_date = dt_ref_fin

while start_date < end_date:
        
    if dt_ref.time()==datetime.time(hour=15, minute=0, second=0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)        
        dt_ref += datetime.timedelta(minutes=120)
        
    if dt_ref.time()==datetime.time(17, 0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)
        dt_ref += datetime.timedelta(minutes=240)
              
    if dt_ref.time()==datetime.time(21, 0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)
        dt_ref += datetime.timedelta(minutes=420)
              
    if dt_ref.time()==datetime.time(4, 0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)
        dt_ref += datetime.timedelta(minutes=240)
        
    if dt_ref.time()==datetime.time(8, 0):  
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)
        dt_ref += datetime.timedelta(minutes=180)
        
    if dt_ref.time()==datetime.time(11, 0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)
        dt_ref += datetime.timedelta(minutes=180)
        
    if dt_ref.time()==datetime.time(hour=14, minute=0, second=0):
        liste_horaire.append(dt_ref.strftime("%Y%m%d_%H%M%S"))
        liste_horaire_V0.append(dt_ref.strftime("%Y%m%d%H%M%S"))        
        liste_horaire_V1.append(dt_ref.strftime("%Y-%m-%d_%H:%M:%S"))
        liste_horaire_V2.append(dt_ref)
        print(dt_ref.strftime("%Y%m%d_%H%M%S"))
        url = "https://www.vendeeglobe.org/download-race-data/vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        filename = "vendeeglobe_"+dt_ref.strftime("%Y%m%d_%H%M%S")+".xlsx"
        with request.urlopen(url) as response, open(filename, 'wb') as out_file:
            copyfileobj(response, out_file)        
        dt_ref += datetime.timedelta(minutes=180)
        
    start_date=dt_ref
# Out:
# 20201108_170000
# 20201108_210000
# 20201109_040000
# 20201109_080000
# 20201109_110000
# 20201109_140000
# 20201109_170000
# 20201109_210000
# 20201110_040000
# 20201110_080000
# 20201110_110000
# 20201110_140000
# 20201110_170000
# 20201110_210000
# 20201111_040000
# 20201111_080000
# 20201111_110000
# 20201111_140000
# 20201111_170000
# 20201111_210000
# 20201112_040000
# 20201112_080000
# 20201112_110000
# 20201112_140000
# 20201112_170000
# 20201112_210000
# 20201113_040000
# 20201113_080000
# 20201113_110000
# 20201113_140000
# 20201113_170000
# 20201113_210000
# 20201114_040000
# 20201114_080000
# 20201114_110000
# 20201114_140000
# 20201114_170000
# 20201114_210000
# 20201115_040000
# 20201115_080000
# 20201115_110000
# 20201115_140000
# 20201115_170000
# 20201115_210000
# 20201116_040000
# 20201116_080000
# 20201116_110000
# 20201116_140000
# 20201116_170000
# 20201116_210000
# 20201117_040000
# 20201117_080000
# 20201117_110000
# 20201117_140000
# 20201117_170000
# ...

# %%
import uuid

import xlwings as xw

# lecture/écriture d'un fichier Excel avec xlwings
def save_with_xlwings(file):
    tempfile = f'./xlwinf_{file}'
    excel_app = xw.App(visible=False)
    excel_book = excel_app.books.open(file)
    excel_book.save(tempfile)
    excel_book.close()
    excel_app.quit()
    return tempfile

# %%
liste_horaire)
# Out:
# 368

# %%
import os
from os import listdir, system
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'projet_test.ipynb',
#  'Untitled.ipynb',
#  'vendeeglobe_20201108_140000.xlsx',
#  'vendeeglobe_20201108_150000.xlsx',
#  'vendeeglobe_20201108_170000.xlsx',
#  'vendeeglobe_20201108_210000.xlsx',
#  'vendeeglobe_20201109_040000.xlsx',
#  'vendeeglobe_20201109_080000.xlsx',
#  'vendeeglobe_20201109_110000.xlsx',
#  'vendeeglobe_20201109_140000.xlsx',
#  'vendeeglobe_20201109_170000.xlsx',
#  'vendeeglobe_20201109_210000.xlsx',
#  'vendeeglobe_20201110_040000.xlsx',
#  'vendeeglobe_20201110_080000.xlsx',
#  'vendeeglobe_20201110_110000.xlsx',
#  'vendeeglobe_20201110_140000.xlsx',
#  'vendeeglobe_20201110_170000.xlsx',
#  'vendeeglobe_20201110_210000.xlsx',
#  'vendeeglobe_20201111_040000.xlsx',
#  'vendeeglobe_20201111_080000.xlsx',
#  'vendeeglobe_20201111_110000.xlsx',
#  'vendeeglobe_20201111_140000.xlsx',
#  'vendeeglobe_20201111_170000.xlsx',
#  'vendeeglobe_20201111_210000.xlsx',
#  'vendeeglobe_20201112_040000.xlsx',
# ...

# %%
for horaire in liste_horaire:
    print(horaire)
    save_with_xlwings(f"vendeeglobe_{horaire}.xlsx")
# Out:
# 20201108_140000
# 20201108_150000
# 20201108_170000
# 20201108_210000
# 20201109_040000
# 20201109_080000
# 20201109_110000
# 20201109_140000
# 20201108_170000
# 20201108_210000
# 20201109_040000
# 20201109_080000
# 20201109_110000
# 20201109_140000
# 20201109_170000
# 20201109_210000
# 20201110_040000
# 20201110_080000
# 20201110_110000
# 20201110_140000
# 20201110_170000
# 20201110_210000
# 20201111_040000
# 20201111_080000
# 20201111_110000
# 20201111_140000
# 20201111_170000
# 20201111_210000
# 20201112_040000
# 20201112_080000
# 20201112_110000
# 20201112_140000
# 20201112_170000
# 20201112_210000
# 20201113_040000
# 20201113_080000
# 20201113_110000
# 20201113_140000
# 20201113_170000
# 20201113_210000
# 20201114_040000
# 20201114_080000
# 20201114_110000
# 20201114_140000
# 20201114_170000
# 20201114_210000
# 20201115_040000
# 20201115_080000
# 20201115_110000
# 20201115_140000
# 20201115_170000
# 20201115_210000
# 20201116_040000
# 20201116_080000
# 20201116_110000
# ...

# %%
# importing the required modules
import glob
import pandas as pd
 
# specifying the path to csv files
path = "C:/Users/User/3D Objects/BGD/PROJET KIT BIG DATA"
 
# csv files in the path
#file_list = glob.glob(path + "/*.xlsx")
 
# list of excel files we want to merge.
# pd.read_excel(file_path) reads the excel
# data into pandas dataframe.
excl_list = []
df=pd.DataFrame()
for horaire,horaire_V1 in zip(liste_horaire,liste_horaire_V1):
    #print(horaire)
    
    dfs = (pd.read_excel(f"xlwinf_vendeeglobe_{horaire}.xlsx", index_col=None, header=None, skiprows=5, skipfooter=4,
                      names=["rank", "nat_sail", "skipper_crew", "hour_FR", "latitude", "longitude",
                            "heading_since_30_mn", "speed_since_30_mn", "VMG_since_30_mn", "distance_since_30_mn",
                            "heading_since_last_report", "speed_since_last_report", "VMG_since_last_report", "distance_since_last_report",
                            "heading_since_24_hr", "speed_since_24_hr", "VMG_since_24_hr", "distance_since_24_hr",
                            "DTF", "DTL"]).assign(heure_bis=horaire_V1))
    
    df = (pd.concat([df, dfs], ignore_index=True).loc[:, ["rank", "nat_sail", "skipper_crew", "hour_FR", "latitude", "longitude",
                            "heading_since_30_mn", "speed_since_30_mn", "VMG_since_30_mn", "distance_since_30_mn",
                            "heading_since_last_report", "speed_since_last_report", "VMG_since_last_report", "distance_since_last_report",
                            "heading_since_24_hr", "speed_since_24_hr", "VMG_since_24_hr", "distance_since_24_hr",
                            "DTF", "DTL", "heure_bis"]])

# %%
df
# Out:
#       rank   nat_sail                                       skipper_crew  \
# 0        1   \nFRA 18                      Louis Burton\nBureau Vallée 2
# 1        2   \nMON 10  Boris Herrmann\nSeaexplorer - Yacht Club De Mo...
# 2        3    \nFRA 8                              Jérémie Beyou\nCharal
# 3        4   \nFRA 59                           Thomas Ruyant\nLinkedOut
# 4        5   \nFRA 53                      Maxime Sorel\nV And B Mayenne
# ...    ...        ...                                                ...
# 12139  RET  \nFRA 109               Samantha Davies\nInitiatives - Coeur
# 12140  RET    \nFRA 4                      Sébastien Simon\nARKEA PAPREC
# 12141  RET   \nGBR 99                            Alex Thomson\nHUGO BOSS
# 12142  RET   \nFRA 85                               Kevin Escoffier\nPRB
# 12143  RET    \nFRA 6                  Nicolas Troussel\nCORUM L'Épargne
#
#               hour_FR    latitude   longitude heading_since_30mn  \
# ...

# %%
df.head()
# Out:
#   rank  nat_sail                                       skipper_crew  \
# 0    1  \nFRA 18                      Louis Burton\nBureau Vallée 2
# 1    2  \nMON 10  Boris Herrmann\nSeaexplorer - Yacht Club De Mo...
# 2    3   \nFRA 8                              Jérémie Beyou\nCharal
# 3    4  \nFRA 59                           Thomas Ruyant\nLinkedOut
# 4    5  \nFRA 53                      Maxime Sorel\nV And B Mayenne
#
#           hour_FR    latitude   longitude heading_since_30mn speed_since_30mn  \
# 0      15:30 FR\n  46°24.46'N  01°50.48'W               241°         17.7 kts
# 1  15:31 FR\n1min  46°24.34'N  01°49.82'W               241°         11.1 kts
# 2      15:30 FR\n  46°24.91'N  01°49.99'W               244°         15.5 kts
# 3      15:30 FR\n  46°24.71'N  01°49.68'W               244°         13.2 kts
# 4      15:30 FR\n  46°24.59'N  01°49.56'W               246°         10.9 kts
#
#   VMG_since_30mn distance_since_30mn  ... speed_since_last VMG_since_last  \
# ...

# %%
df.describe()
# Out:
#          rank  nat_sail                   skipper_crew     hour_FR  \
# count   12144     12144                          12144       10831
# unique     67        33                             34          41
# top       RET  \nFRA 18  Louis Burton\nBureau Vallée 2  14:30 FR\n
# freq     1307       368                            368        1559
#
#           latitude   longitude heading_since_30mn speed_since_30mn  \
# count        10831       10831              10831            10831
# unique       10392       10506                344              236
# top     46°30.11'N  01°47.45'W                90°         15.3 kts
# freq            19          19                145              128
#
#        VMG_since_30mn distance_since_30mn  ... speed_since_last  \
# count           10831               10831  ...            10831
# unique            295                 138  ...              229
# top          12.0 kts              6.9 nm  ...         13.5 kts
# ...

# %%
df.dtypes
# Out:
# rank                   object
# nat_sail               object
# skipper_crew           object
# hour_FR                object
# latitude               object
# longitude              object
# heading_since_30mn     object
# speed_since_30mn       object
# VMG_since_30mn         object
# distance_since_30mn    object
# heading_since_last     object
# speed_since_last       object
# VMG_since_last         object
# distance_since_last    object
# heading_since_24hr     object
# speed_since_24hr       object
# VMG_since_24hr         object
# distance_since_24hr    object
# DTF                    object
# DTL                    object
# date_hours             object
# dtype: object

# %% [markdown]
# conversion et nettoyage du dataframe

# %%
df.columns
# Out:
# Index(['rank', 'nat_sail', 'skipper_crew', 'hour_FR', 'latitude', 'longitude',
#        'heading_since_30mn', 'speed_since_30mn', 'VMG_since_30mn',
#        'distance_since_30mn', 'heading_since_last', 'speed_since_last',
#        'VMG_since_last', 'distance_since_last', 'heading_since_24hr',
#        'speed_since_24hr', 'VMG_since_24hr', 'distance_since_24hr', 'DTF',
#        'DTL', 'heure_bis'],
#       dtype='object')

# %%
df.head()
# Out:
#   rank  nat_sail                                       skipper_crew  \
# 0    1  \nFRA 18                      Louis Burton\nBureau Vallée 2
# 1    2  \nMON 10  Boris Herrmann\nSeaexplorer - Yacht Club De Mo...
# 2    3   \nFRA 8                              Jérémie Beyou\nCharal
# 3    4  \nFRA 59                           Thomas Ruyant\nLinkedOut
# 4    5  \nFRA 53                      Maxime Sorel\nV And B Mayenne
#
#           hour_FR    latitude   longitude heading_since_30mn speed_since_30mn  \
# 0      15:30 FR\n  46°24.46'N  01°50.48'W               241°         17.7 kts
# 1  15:31 FR\n1min  46°24.34'N  01°49.82'W               241°         11.1 kts
# 2      15:30 FR\n  46°24.91'N  01°49.99'W               244°         15.5 kts
# 3      15:30 FR\n  46°24.71'N  01°49.68'W               244°         13.2 kts
# 4      15:30 FR\n  46°24.59'N  01°49.56'W               246°         10.9 kts
#
#   VMG_since_30mn distance_since_30mn  ... speed_since_last VMG_since_last  \
# ...

# %%
df
# Out:
#       rank nat_sail     hour_FR    latitude   longitude heading_since_30_mn  \
# 0        1   FRA 18      15:30   46°24.46'N  01°50.48'W                 241
# 1        2   MON 10  15:31 1min  46°24.34'N  01°49.82'W                 241
# 2        3    FRA 8      15:30   46°24.91'N  01°49.99'W                 244
# 3        4   FRA 59      15:30   46°24.71'N  01°49.68'W                 244
# 4        5   FRA 53      15:30   46°24.59'N  01°49.56'W                 246
# ...    ...      ...         ...         ...         ...                 ...
# 12139  RET  FRA 109         NaN         NaN         NaN                 NaN
# 12140  RET    FRA 4         NaN         NaN         NaN                 NaN
# 12141  RET   GBR 99         NaN         NaN         NaN                 NaN
# 12142  RET   FRA 85         NaN         NaN         NaN                 NaN
# 12143  RET    FRA 6         NaN         NaN         NaN                 NaN
#
# ...

# %%
df.tail(30)
# Out:
#        rank  nat_sail hour_FR    latitude    longitude heading_since_30_mn  \
# 12102    25    FRA 72  11:30   54°30.15'S  179°17.36'E                  59
# 12103    26   FIN 222  11:30   50°24.54'S  173°44.76'E                  84
# 12104    27  FRFRA 69  11:30   49°58.17'S  128°26.52'E                 112
# 12111     1    FRA 17  14:30   37°08.41'S   44°22.22'W                 360
# 12112     2    FRA 59  14:30   42°07.49'S   52°32.62'W                   0
# 12113     3    FRA 79  14:30   42°31.36'S   51°40.99'W                  10
# 12114     4  FRA 1000  14:30   46°16.12'S   42°44.45'W                  65
# 12115     5    FRA 18  14:30   47°33.52'S   43°41.14'W                  59
# 12116     6    FRA 09  14:30   47°30.42'S   46°53.78'W                  71
# 12117     7    FRA 01  14:30   48°18.85'S   45°31.75'W                  54
# 12118     8    ITA 34  14:30   48°50.85'S   47°02.20'W                  57
# ...

# %%
#suppression des espaces et des unités
df['nat_sail'] = df['nat_sail'].str.replace("\n","")
#df[['skipper','srew']] = df['skipper_crew'].str.split("\n",expand=True)
#df = df.drop(columns=['skipper_crew'], axis=1)
df['hour_FR'] = df['hour_FR'].str.replace("FR\n","")
df['heading_since_30_mn'] = df['heading_since_30_mn'].str.replace("°","")
df['speed_since_30_mn'] = df['speed_since_30_mn'].str.replace("kts","")
df['VMG_since_30_mn'] = df['VMG_since_30_mn'].str.replace("kts","")
df['distance_since_30_mn'] = df['distance_since_30_mn'].str.replace("nm","")
df['heading_since_24_hr'] = df['heading_since_24_hr'].str.replace("°","")
df['speed_since_24_hr'] = df['speed_since_24_hr'].str.replace("kts","")
df['VMG_since_24_hr'] = df['VMG_since_24_hr'].str.replace("kts","")
df['distance_since_24_hr'] = df['distance_since_24_hr'].str.replace("nm","")
df['heading_since_last_report'] = df['heading_since_last_report'].str.replace("°","")
df['speed_since_last_report'] = df['speed_since_last_report'].str.replace("kts","")
df['VMG_since_last_report'] = df['VMG_since_last_report'].str.replace("kts","")
df['distance_since_last_report'] = df['distance_since_last_report'].str.replace("nm","")
df['DTF'] = df['DTF'].str.replace("nm","")
df['DTL'] = df['DTL'].str.replace("nm","")
df = df[df['rank'].notna()]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       rank  nat_sail     hour_FR    latitude    longitude heading_since_30_mn  \
# 0        1    FRA 18      15:30   46°24.46'N   01°50.48'W                 241
# 1        2    MON 10  15:31 1min  46°24.34'N   01°49.82'W                 241
# 2        3     FRA 8      15:30   46°24.91'N   01°49.99'W                 244
# 3        4    FRA 59      15:30   46°24.71'N   01°49.68'W                 244
# 4        5    FRA 53      15:30   46°24.59'N   01°49.56'W                 246
# ...    ...       ...         ...         ...          ...                 ...
# 12133   23    FRA 50      14:30   51°51.82'S  150°30.28'W                  28
# 12134   24    FRA 83      14:30   52°08.16'S  151°54.01'W                  80
# 12135   25    FRA 72      14:30   54°19.59'S  179°56.96'E                  54
# 12136   26   FIN 222      14:30   50°18.66'S  174°40.49'E                  80
# 12137   27  FRFRA 69      14:30   49°54.09'S  128°40.97'E                  38
#
# ...

# %% [markdown]
# conversion des données en données numériques

# %%
df['rank'] = pd.to_numeric(df['rank'])
df['VMG_since_last_report'] = pd.to_numeric(df['VMG_since_last_report'])

# %%
df.to_pickle("./df_pickle.pkl")

# %%
df2.astype(numpy.float64)

# %% [markdown]
# # Scrapping

# %% [markdown]
# scrapping page glosssaire

# %%
# imports
import requests
from bs4 import BeautifulSoup
from lxml import etree

# %%
url = "https://www.vendeeglobe.org/fr/glossaire"
res = requests.get(url)
content = res.content.decode('utf-8')
soup = BeautifulSoup(content)
voilier_name = soup.find_all('div', class_='boats-list__infos')
voilier_carac = soup.find_all('div', {'class': "boats-list__popup-infos"})

# %%
voilier_infos = [i.text for i in soup.find_all("ul", {"class":"boats-list__popup-specs-list"})]
voilier_name = [i.text.title() for i in soup.find_all("span", {"class":"boats-list__skipper-name"})]

# %%
tmp = [i.split(" : ") for i in voilier_infos[0].split('\n')[1:-1]]
names = [tmp[i][0] for i in range(len(tmp))]
values = [tmp[i][1] for i in range(len(tmp))]
df_boat = pd.DataFrame([values], columns=names)

# %%
for j in range(1, len(voilier_infos)):
    tmp = [i.split(" : ") for i in voilier_infos[j].split('\n')[1:-1]]
    names = [tmp[i][0] for i in range(len(tmp))]
    values = [tmp[i][1] for i in range(len(tmp))]
    df_bis = pd.DataFrame([values], columns=names)
    df_boat = df_boat.merge(df_bis, how='outer')

# %%
voilier_names = [voilier_name[i].title() for i in range(len(voilier_name))]
df_boat['Skipper'] = voilier_names
df_boat.to_pickle("bateaux.pkl")
df_boat.head()
df_boat.dropna(inplace=True)
# Out:
#   Numéro de voile                             Anciens noms du bateau  \
# 0          FRA 56                     No Way Back, Vento di Sardegna
# 1          FRA 49           Gitana Eighty, Synerciel, Newrest-Matmut
# 2           FRA72  Famille Mary-Etamine du Lys, Initiatives Coeur...
# 3              17                      Safran 2 - Des Voiles et Vous
# 4              08                                                NaN
#
#           Architecte                                  Chantier  \
# 0       VPLP/Verdier                            Persico Marine
# 1  Bruce Farr Design  Southern Ocean Marine (Nouvelle Zélande)
# 2       Marc Lombard                                MAG France
# 3     Verdier - VPLP                          CDK Technologies
# 4               VPLP                          CDK Technologies
#
#   Date de lancement Longueur Largeur Tirant d'eau Déplacement (poids)  \
# 0      01 Août 2015  18,28 m  5,85 m       4,50 m                 7 t
# ...

# %%
df_boat['Longueur'] = df_boat['Longueur'].str.replace("m","")
df_boat['Largeur'] = df_boat['Largeur'].str.replace("m","")
df_boat["Tirant d'eau"] = df_boat["Tirant d'eau"].str.replace("m","")
df_boat['Déplacement (poids)'] = df_boat['Déplacement (poids)'].str.replace("t","")
df_boat['Hauteur mât'] = df_boat['Hauteur mât'].str.replace("m","")
df_boat['Surface de voiles au près'] = df_boat['Surface de voiles au près'].str.replace("m2","")
df_boat['Surface de voiles au près'] = df_boat['Surface de voiles au près'].str.replace("m²","")
df_boat['Surface de voiles au portant'] = df_boat['Surface de voiles au portant'].str.replace("m2","")
df_boat['Surface de voiles au portant'] = df_boat['Surface de voiles au portant'].str.replace("m²","")

# %%
df_boat.dropna(inplace=True)

# %%
df_boat
# Out:
#    Numéro de voile                             Anciens noms du bateau  \
# 0           FRA 56                     No Way Back, Vento di Sardegna
# 1           FRA 49           Gitana Eighty, Synerciel, Newrest-Matmut
# 2            FRA72  Famille Mary-Etamine du Lys, Initiatives Coeur...
# 3               17                      Safran 2 - Des Voiles et Vous
# 5           FRA 14  Ecover3, Président, Gamesa, Kilcullen Voyager-...
# 6               18                              Banque Populaire VIII
# 7           ESP 33  Kingfisher - Educacion sin Fronteras - Forum M...
# 8           FRA 71  Paprec-Virbac2, Estrella Damm, We are Water, L...
# 9            FRA30                                        Macif - SMA
# 11          FRA109       Maître CoQ - Banque Populaire VII- Foncia II
# 12              69              Foresight Natural Energy, Maisonneuve
# 13           FRA09  Spirit of Yukoh, Neutrogena, Hugo Boss, Estrel...
# ...

# %%
df_boat.to_pickle("./df_boat.pkl")

# %%
boat = []
skipper = []
for i in voilier_name:
    boat.append(i.find('h3').text)
    skipper.append(i.find('span').text)

# %%
skipper
# Out:
# ['Fabrice AMEDEO',
#  'Romain ATTANASIO',
#  'Alexia BARRIER',
#  'Yannick BESTAVEN',
#  'Jérémie BEYOU',
#  'Arnaud BOISSIÈRES',
#  'Louis BURTON',
#  'Didac COSTA',
#  'Manuel COUSIN',
#  'Clarisse CREMER',
#  'Charlie DALIN',
#  'Sam DAVIES',
#  'Sébastien DESTREMAU',
#  'Benjamin DUTREUX',
#  'Kevin ESCOFFIER',
#  'Clément GIRAUD',
#  'François Guiffant',
#  'Pip HARE',
#  'Boris HERRMANN',
#  'Ari HUUSELA',
#  'Isabelle JOSCHKE',
#  'Jean LE CAM',
#  'Stéphane LE DIRAISON',
#  'Miranda MERRON',
#  'Giancarlo PEDOTE',
#  'Alan  ROURA',
#  'Thomas RUYANT',
#  'Damien SEGUIN',
#  'Kojiro SHIRAISHI',
#  'Sébastien SIMON',
#  'Maxime SOREL',
#  'Alex THOMSON',
#  'Armel TRIPON',
#  'Nicolas TROUSSEL']

# %%
#on traite le scrap html afin d'extraire les caractéristiques de chaque bateau sous forme d'un dictionnaire avec son nom comme clé
voilier_dict = {}
for voilier in voilier_name:
    voilier_dict[voilier.find('h3', {'class': "boats-list__popup-title"}).text] = {}
    voilier_dict_ls= voilier.find_all('li')
    for carac_voilier in boat_spec_ls:
        spec = str(spec)[4:-5]
        spec_split = spec.split(" : ")
        boat_dict[boat.find('h3', {'class': "boats-list__popup-title"}).text][spec_split[0]] = spec_split[1]

# %% [markdown]
# on cree un dico boat skipper

# %%
voilier_carac = voilier_extract.find_all('li')

# %%
boat_infos
# Out:
# ["\nNuméro de voile : FRA 56\nAnciens noms du bateau : No Way Back, Vento di Sardegna\nArchitecte : VPLP/Verdier\nChantier : Persico Marine\nDate de lancement : 01 Août 2015\nLongueur : 18,28 m\nLargeur : 5,85 m\nTirant d'eau : 4,50 m\nDéplacement (poids) : 7 t\nNombre de dérives : foils\nHauteur mât : 29 m\nVoile quille : monotype\nSurface de voiles au près : 320 m2\nSurface de voiles au portant : 570 m2\n",
#  "\nNuméro de voile : FRA 49\nAnciens noms du bateau : Gitana Eighty, Synerciel, Newrest-Matmut\nArchitecte : Bruce Farr Design\nChantier : Southern Ocean Marine (Nouvelle Zélande)\nDate de lancement : 08 Mars 2007\nLongueur : 18,28m\nLargeur : 5,80m\nTirant d'eau : 4,50m\nDéplacement (poids) : 9t\nNombre de dérives : 2\nHauteur mât : 28m\nVoile quille : acier forgé\nSurface de voiles au près : 280 m2\nSurface de voiles au portant : 560 m2\n",
# ...

# %% [markdown]
# # Analyses et story telling

# %%
import math                         # import a package
import numpy as np                  # import a package with specified name
from sklearn import linear_model    # import whole module
from os import mkdir, rmdir, path   # import a function
from inspect import getsourcelines  # get function source code
import random
import string
import time
import pandas as pd
import urllib
import zipfile
import matplotlib.pyplot as plt     # for plots
import seaborn as sns               # for plots
import sys

sns.set_palette("colorblind")
color_blind_list = sns.color_palette("colorblind", 8)

# %%
import sklearn.datasets as skl_data
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error 
from matplotlib import rc
from sklearn.preprocessing import StandardScaler
from statsmodels.nonparametric.kde import KDEUnivariate
from scipy.stats import gaussian_kde
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from numpy.linalg import svd

from IPython.display import HTML
from IPython.display import display

# %%
import scipy.stats as stat
from numpy.linalg import matrix_rank
from scipy.stats import norm

from sklearn.linear_model import Ridge
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
import statistics

# %%
corrélation et regression linéaire

# %%
#on peut effectuer la matrice de covariance et faire un pair plot

# %%
df_analyse=pd.read_pickle('df_pickle.pkl')

# %%
df_analyse
# Out:
#        rank  nat_sail     hour_FR    latitude    longitude  \
# 0         1    FRA 18      15:30   46°24.46'N   01°50.48'W
# 1         2    MON 10  15:31 1min  46°24.34'N   01°49.82'W
# 2         3     FRA 8      15:30   46°24.91'N   01°49.99'W
# 3         4    FRA 59      15:30   46°24.71'N   01°49.68'W
# 4         5    FRA 53      15:30   46°24.59'N   01°49.56'W
# ...     ...       ...         ...         ...          ...
# 12133    23    FRA 50      14:30   51°51.82'S  150°30.28'W
# 12134    24    FRA 83      14:30   52°08.16'S  151°54.01'W
# 12135    25    FRA 72      14:30   54°19.59'S  179°56.96'E
# 12136    26   FIN 222      14:30   50°18.66'S  174°40.49'E
# 12137    27  FRFRA 69      14:30   49°54.09'S  128°40.97'E
#
#       heading_since_30_mn speed_since_30_mn VMG_since_30_mn  \
# 0                     241             17.7            17.5
# 1                     241             11.1            10.9
# 2                     244             15.5            15.5
# ...

# %%
df_skipper = df.groupby(['Skipper']).mean()
df_skipper.sort_values('rank', ascending=True,inplace=True)

# %%
df_skipper
# Out:
#                            rank  VMG_since_last_report
# Skipper
# Charlie Dalin          2.803815              12.772752
# Thomas Ruyant          3.692935              12.711141
# Yannick Bestaven       4.562500              13.094837
# Jean Le Cam            4.766304              12.583696
# Kevin Escoffier        6.293706              12.116783
# Damien Seguin          6.923913              12.770109
# Nicolas Troussel       7.232143               9.864286
# Benjamin Dutreux       7.516304              12.643750
# Alex Thomson           7.555556              11.064198
# Boris Herrmann         7.801630              12.658696
# Louis Burton           8.209239              12.831250
# Samantha Davies       10.449704              10.600592
# Sébastien Simon       10.615854              11.385976
# Maxime Sorel          10.831522              12.502717
# Giancarlo Pedote      11.480978              12.601087
# Isabelle Joschke      11.586957              12.487228
# ...

# %%
plt.plot(df_skipper["rank"], df_skipper["VMG_since_last_report"], 'o')
plt.xlabel('Rang du skipper')
plt.ylabel('Vitesse moyenne utile VMG(kts) du voilier en fonction du rank');

# %% [markdown]
# on voit que la courbe est decroissante ainsi plus la vitesse est élevé plus le skipper est bien classé

# %%
df['rank'].corr(df['VMG_since_last_report'])
# Out:
# -0.32164987044514776

# %%
df.corr()
# Out:
#                           rank  VMG_since_last_report
# rank                   1.00000               -0.32165
# VMG_since_last_report -0.32165                1.00000

# %% [markdown]
# on remarque cependant que la vitesse utile VMG n'est pas la seule variable determinant le rang du skipper

# %%
plt.figure()
df_skipper["rank"].plot(kind='bar',color='b', alpha=0.4)
df_skipper["VMG_since_last_report"].plot(kind='bar',color='y', alpha=0.4)
plt.title("rang du skipper en fonction de la VMG utile")
plt.show()

# %% [markdown]
# on retrouve l'idée que plus la vitesse utile VMG est éleve meilleur est le rang, cependant d'autre facteurs comme l'itinéraire de parcours doivent également intervenir

# %%
plt.figure()
sns.pairplot(pd.DataFrame(df_skipper[["rank","VMG_since_last_report"]], columns=['X1', 'X2']))
plt.title("scatter plot de covariables")
# Out:
# Text(0.5, 1.0, 'scatter plot de covariables')

# %%
reg = linear_model.LinearRegression()
X = df_skipper['VMG_since_last_report'].values.reshape(-1,1)
y = df_skipper["rank"].values.reshape(-1,1)
reg.fit(X, y)
print('Le score de la régression est : ',reg.score(X, y))
print('Les coeffs sont : ',reg.coef_)
print("L'intercept est : ",reg.intercept_)

x_print = df_skipper["rank"]
y_print = reg.coef_[0]*df_skipper["rank"]+reg.intercept_
# Out:
# Le score de la régression est :  0.631799426739936
# Les coeffs sont :  [[-4.742163]]
# L'intercept est :  [68.61718123]

# %%
x_reg = np.linspace(8,13,100)
y_reg = reg.coef_[0]*x_reg+reg.intercept_
plt.plot(X, y,'o')
plt.plot(x_reg, y_reg, label='Régression du rank en fonction de la vitesse moyenne')
plt.ylabel('Rang')
plt.xlabel('Vitesse moyenne utile VMG(kts) du voilier en fonction du rank')
plt.legend();

# %% [markdown]
# # impact du foil sur le classement et la vitesse des voiliers

# %% [markdown]
# on compare avec et sans foil pour voir l'impact au niveau des vitesses

# %%
df_derive = df_skipper.reset_index().merge(df_boat)[['Nombre de dérives', 'rank', 'VMG_since_last_report']]

# %% [markdown]
# on remarque une amelioration de la vitesse avec foil

# %%
df_derive_foil
# Out:
#    Nombre de dérives       rank  VMG_since_last_report
# 0              foils   4.562500              13.094837
# 1                  2   4.766304              12.583696
# 2                  2   6.923913              12.770109
# 3                  2   7.516304              12.643750
# 4              foils   7.801630              12.658696
# 5              foils   8.209239              12.831250
# 6                  2  10.831522              12.502717
# 7              foils  11.480978              12.601087
# 8              foils  11.586957              12.487228
# 9                  2  13.459239              12.104620
# 10                 2  14.195652              12.293207
# 11             foils  17.720109              10.937228
# 12                 2  20.013587              11.226630
# 13                 2  20.190217              10.907880
# 14    2 asymétriques  20.994565              10.515489
# 15                 2  24.345109              10.056793
# ...

# %%
df_derive_foil=df_derive[df_derive["Nombre de dérives"]=="foils"]

# %%
df_derive_sans_foil=df_derive[df_derive["Nombre de dérives"]!="foils"]

# %%
plt.plot(df_derive_foil["rank"], df_derive_foil["VMG_since_last_report"], 'o', color='b', label='boat avec foil')
plt.plot(df_derive_sans_foil["rank"], df_derive_sans_foil["VMG_since_last_report"], 'o', color='r', label='boat sans foil')
plt.xlabel('Rang du skipper')
plt.ylabel('Vitesse moyenne utile VMG(kts) du voilier en fonction du rank');

# %% [markdown]
# on remarque que la presence de foil a pour conséquence une VMG vitesse moyenne utile plus importante

# %% [markdown]
# # Variable d'importances PCA

# %% [markdown]
# On essaie d'appliquer la PCA au foil pour voir si ce sont des variables d'importances

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
#mappage des valeurs
df_derive.dropna(inplace=True)
df_derive['Nombre de dérives'] = df_derive["Nombre de dérives"].map({True: 1, False: 0})
df_derive.dropna(inplace=True)
X = df_derive[['VMG_since_last_report', "Nombre de dérives"]].to_numpy()
pca.fit(X)
print("variance pca " ,pca.explained_variance_ratio_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [225], in <module>
#       6 df_derive.dropna(inplace=True)
#       7 X = df_derive[['VMG_since_last_report', "Nombre de dérives"]].to_numpy()
# ----> 8 pca.fit(X)
#       9 print("variance pca " ,pca.explained_variance_ratio_)
#      10 print("Valeurs singulières SVD ", pca.singular_values_)
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\decomposition\_pca.py:408, in PCA.fit(self, X, y)
#     385 """Fit the model with X.
#     386
#     387 Parameters
#    (...)
#     399     Returns the instance itself.
#     400 """
#     401 check_scalar(
#     402     self.n_oversamples,
#     403     "n_oversamples",
#     404     min_val=1,
#     405     target_type=numbers.Integral,
#     406 )
# --> 408 self._fit(X)
#     409 return self
#
# ...

# %% [markdown]
# # Analyse de serie temporelle

# %% [markdown]
# l'importation nous a permis d'avoir une colonne correspondant au temps ce qui facilite l'analyse temporelle on peut ainsi ploter l'evolution du rang en fonction du temps

# %%
pd.to_datetime(df["heure_bis"], format='%Y-%m-%d_%H:%M:%S')
# Out:
# 0       2020-11-08 14:00:00
# 1       2020-11-08 14:00:00
# 2       2020-11-08 14:00:00
# 3       2020-11-08 14:00:00
# 4       2020-11-08 14:00:00
#                 ...
# 12133   2021-01-07 14:00:00
# 12134   2021-01-07 14:00:00
# 12135   2021-01-07 14:00:00
# 12136   2021-01-07 14:00:00
# 12137   2021-01-07 14:00:00
# Name: heure_bis, Length: 10831, dtype: datetime64[ns]

# %%
df_name= df.groupby(['Skipper'])

# %%
df_name.head()
# Out:
#      rank nat_sail     hour_FR    latitude   longitude heading_since_30_mn  \
# 0       1   FRA 18      15:30   46°24.46'N  01°50.48'W                 241
# 1       2   MON 10  15:31 1min  46°24.34'N  01°49.82'W                 241
# 2       3    FRA 8      15:30   46°24.91'N  01°49.99'W                 244
# 3       4   FRA 59      15:30   46°24.71'N  01°49.68'W                 244
# 4       5   FRA 53      15:30   46°24.59'N  01°49.56'W                 246
# ..    ...      ...         ...         ...         ...                 ...
# 164    33   FRA 56      05:30   46°29.32'N  01°47.21'W                 215
# 184    20   FRA 14      09:00   46°26.61'N  06°55.92'W                 289
# 189    25   FRA 79      09:00   46°54.58'N  08°16.41'W                 294
# 227    30   FRA 14      12:00   46°41.16'N  07°32.89'W                 312
# 260    30   FRA 14      15:00   46°33.44'N  07°52.03'W                 190
#
#     speed_since_30_mn VMG_since_30_mn distance_since_30_mn  \
# ...

# %%
rank = df['rank'].loc[(df["Skipper"] == "Thomas Ruyant")]
temps = df['heure_bis'].loc[(df["Skipper"] == "Thomas Ruyant")]
plt.plot(temps, rank, label = "Thomas Ruyant")
plt.xlabel("temps")
plt.ylabel("rank du skipper Thomas Ruyant")
plt.legend()

# %%
vitesse = df['VMG_since_last_report'].loc[(df["Skipper"] == "Thomas Ruyant")]
temps = df['heure_bis'].loc[(df["Skipper"] == "Thomas Ruyant")]
plt.plot(temps, vitesse, label = "Thomas Ruyant")
plt.xlabel("temps")
plt.ylabel("vitesse du skipper Thomas Ruyant")
plt.legend()

# %% [markdown]
# on remarque pour le deuxieme skipper que malgré un mauvais depart il a reussi à maintenir sa place tout au long de la course

# %% [markdown]
# le deuxieme skipper a un mauvais classement malgré une bonne vitesse en debut de course, il arrive également à maintenir son rang malgré une chute de vitesse en fin de premiere partie de course

# %% [markdown]
# il perd cependant des places vers la fin de course en parallele avec sa perte de vitesse

# %% [markdown]
# il peut également etre interesant de comparer le profil des  premiers skipper

# %%
vitesse = df['VMG_since_last_report'].loc[(df["Skipper"] == "Boris Herrmann")]
temps = df['heure_bis'].loc[(df["Skipper"] == "Boris Herrmann")]
plt.plot(temps, vitesse, label = "Boris Herrmann")
plt.xlabel("temps")
plt.ylabel("vitesse du skipper Boris Herrmann")
plt.legend()

# %%
rank = df['rank'].loc[(df["Skipper"] == "Boris Herrmann")]
temps = df['heure_bis'].loc[(df["Skipper"] == "Boris Herrmann")]
plt.plot(temps, rank, label = "Boris Herrmann")
plt.xlabel("temps")
plt.ylabel("rank du skipper Boris Herrmann")
plt.legend()

# %% [markdown]
# il est interessant de voir que les skipper ont des profils de vitesse similaires et rank assez proche

# %% [markdown]
# on remarque également que la première partie de course est peu importante ou decisive par rapport à l'issue finale

# %% [markdown]
# # DISTANCE EN FONCTION DU TEMPS

# %%
DISTANCE = df['distance_since_last_report'].loc[(df["Skipper"] == "Boris Herrmann")]
temps = df['heure_bis'].loc[(df["Skipper"] == "Boris Herrmann")]
plt.plot(temps, DISTANCE, '.', label = "Boris Herrmann")
plt.title("distance en fonction du temps Boris Herrmann")
plt.xlabel("temps")
plt.ylabel("DISTANCE du skipper Boris Herrmann")
plt.legend()

# %% [markdown]
# on remarque que la distance en fonction du temps est lineaire et donc que la vitesse moyenne est plus ou moins constante
